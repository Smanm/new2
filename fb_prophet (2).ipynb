# %%
from selenium import webdriver
import time
import pandas as pd
import requests
import json
from fbprophet import Prophet
# Out:
# Importing plotly failed. Interactive plots will not work.

# %%
import warnings;
warnings.simplefilter('ignore')

# %%
path=r'C:\Users\hp\Downloads\chromedriver_win32 (1)\chromedriver.exe'
browser=webdriver.Chrome(executable_path=path)

# %%
browser.get('https://data.covid19india.org/')

# %%
data=browser.find_element_by_xpath('/html/body/div/table[1]/tbody/tr[1]/td[2]/a')

# %%
data.click()

# %%
time.sleep(10)

# %%
r=requests.get('https://data.covid19india.org/v4/min/timeseries.min.json')

# %%
column_name=['dates','total_confirmed','total deceased']
Df=pd.DataFrame(columns=column_name)
Df
column_name=['dates','total_confirmed','total deceased']
D_frame=pd.DataFrame(columns=column_name)
D_frame
# Out:
# Empty DataFrame
# Columns: [dates, total_confirmed, total deceased]
# Index: []

# %%
state={"Abbreviation":['AN','AP','AR','AS','BR','CH','CT','DN','DD','DL','GA','GJ','HR','HP','JK','JH','KA','KL','LD','MP','MH','MN','ML','MZ','NL','OR','PY','PB','RJ','SK','TN','TG','TR','UP','UT','WB'],"State":["Andaman and Nicobar Islands","Andhra Pradesh","Arunachal Pradesh","Assam","Bihar","Chandigarh","Chattisgarh","Dadea and Nagar Haveli","Daman and Diu","Delhi","Goa","Gujarat","Haryana","Himachal Pradesh","Jammu and Kashmir","Jharkhand","Karnataka","Kerala","Lakshadweep","Madhya Pradesh","Maharashtra","Manipur","Meghalaya","Mizoram","Nagaland","Odisha","Puducherry","Punjab","Rajasthan","Sikkim","Tamil Nadu","Telengana","Tripura","Uttar Pradesh","Uttrakhand","West Bengal"]}
state_name=pd.DataFrame(state)
state_name
# Out:
#    Abbreviation                        State
# 0            AN  Andaman and Nicobar Islands
# 1            AP               Andhra Pradesh
# 2            AR            Arunachal Pradesh
# 3            AS                        Assam
# 4            BR                        Bihar
# 5            CH                   Chandigarh
# 6            CT                  Chattisgarh
# 7            DN       Dadea and Nagar Haveli
# 8            DD                Daman and Diu
# 9            DL                        Delhi
# 10           GA                          Goa
# 11           GJ                      Gujarat
# 12           HR                      Haryana
# 13           HP             Himachal Pradesh
# 14           JK            Jammu and Kashmir
# 15           JH                    Jharkhand
# 16           KA                    Karnataka
# 17           KL                       Kerala
# 18           LD                  Lakshadweep
# 19           MP               Madhya Pradesh
# 20           MH                  Maharashtra
# 21           MN                      Manipur
# 22           ML                    Meghalaya
# 23           MZ                      Mizoram
# 24           NL                     Nagaland
# 25           OR                       Odisha
# 26           PY                   Puducherry
# 27           PB                       Punjab
# 28           RJ                    Rajasthan
# 29           SK                       Sikkim
# 30           TN                   Tamil Nadu
# 31           TG                    Telengana
# 32           TR                      Tripura
# 33           UP                Uttar Pradesh
# 34           UT                   Uttrakhand
# 35           WB                  West Bengal

# %%
state_ab=input("ENTER THE STATE ABBREVIATION FROM ABOVE AN/GA/MH ")
# Out:
# ENTER THE STATE ABBREVIATION FROM ABOVE AN/GA/MH KL

# %%
x=pd.datetime.now().year

# %%
x=x%10

# %%
x
# Out:
# 1

# %%
Dat0={}
data0=json.loads(r.text)[state_ab]['dates']['2020-1{}-3{}'.format(2,1)]['total']['confirmed']
Data0=json.loads(r.text)[state_ab]['dates']['2020-1{}-3{}'.format(2,1)]['total']['deceased']
#data1=json.loads(r.text)['KL']['dates']
#print((data))
Dat0[Df.columns[0]]=str(['20201{}3{}'.format(2,1)])
Dat0[Df.columns[1]]=data0
Dat0[Df.columns[2]]=Data0
Df=Df.append(Dat0,ignore_index=True)
for y in range(x):
    for k in range(9):
        for i in range(9):
            try:
                Dat={}
           
            
                data1=json.loads(r.text)[state_ab]['dates']['202{}-0{}-0{}'.format(y+1,k+1,i+1)]['total']['confirmed']
                Data1=json.loads(r.text)[state_ab]['dates']['202{}-0{}-0{}'.format(y+1,k+1,i+1)]['total']['deceased']
        
                Dat[Df.columns[0]]=str('202{}/{}/{}'.format(y+1,k+1,i+1))
           
                Dat[Df.columns[1]]=data1
                Dat[Df.columns[2]]=Data1
                Df=Df.append(Dat,ignore_index=True)
                D_frame=D_frame.append(Dat,ignore_index=True)
        
            except:
                continue
        for j in range(22):
            try:
                Dat2={}
                data2=json.loads(r.text)[state_ab]['dates']['202{}-0{}-{}'.format(y+1,k+1,j+10)]['total']['confirmed']
                Data2=json.loads(r.text)[state_ab]['dates']['202{}-0{}-{}'.format(y+1,k+1,j+10)]['total']['deceased']
        
                Dat2[Df.columns[0]]=str('202{}/{}/{}'.format(y+1,k+1,j+10))
           
                Dat2[Df.columns[1]]=data2
                Dat2[Df.columns[2]]=Data2
            
                Df=Df.append(Dat2,ignore_index=True)
                D_frame=D_frame.append(Dat2,ignore_index=True)
        
            except:
                continue         
    for k in range(3):
        for i in range(9):
            try:
                Dat={}
           
            
                data1=json.loads(r.text)[state_ab]['dates']['202{}-{}-0{}'.format(y+1,k+10,i+1)]['total']['confirmed']
                Data1=json.loads(r.text)[state_ab]['dates']['202{}-{}-0{}'.format(y+1,k+10,i+1)]['total']['deceased']
       
                Dat[Df.columns[0]]=str('202{}/{}/{}'.format(y+1,k+10,i+1))
           
                Dat[Df.columns[1]]=data1
                Dat[Df.columns[2]]=Data1
                Df=Df.append(Dat,ignore_index=True)
                D_frame=D_frame.append(Dat,ignore_index=True)
        
            except:
                continue
        for j in range(22):
            try:
                Dat2={}
                data2=json.loads(r.text)[state_ab]['dates']['202{}-{}-1{}'.format(y+1,k+10,j+10)]['total']['confirmed']
                Data2=json.loads(r.text)[state_ab]['dates']['202{}-{}-1{}'.format(y+1,k+10,j+10)]['total']['deceased']
        
                Dat2[Df.columns[0]]=str('202{}/{}/{}'.format(y+1,k+10,j+10))
           
                Dat2[Df.columns[1]]=data2
                Dat2[Df.columns[2]]=Data2
            
                Df=Df.append(Dat2,ignore_index=True)
                D_frame=D_frame.append(Dat2,ignore_index=True)
        
            except:
                continue

# %%
display(Df)
# Out:
#             dates total_confirmed total deceased
# 0    ['20201231']          760934           3073
# 1        2021/1/1          765925           3096
# 2        2021/1/2          771253           3117
# 3        2021/1/3          775853           3142
# 4        2021/1/4          778874           3161
# ..            ...             ...            ...
# 278     2021/10/5         4738791          25677
# 279     2021/10/6         4751407          25811
# 280     2021/10/7         4763695          25952
# 281     2021/10/8         4774639          26072
# 282     2021/10/9         4784109          26173
#
# [283 rows x 3 columns]

# %%
#n_rows=Df.shape[0]
#Df.dtypes
#n_rows

# %%
#pd.set_option('display.max_rows',n_rows)
#D_frame=D_frame.rename(columns={"total_confirmed":"active_cases"})
#D_frame=D_frame.rename(columns={"total deceased":"daily deaths"})

# %%
#D_frame
# Out:
#          dates active_cases daily deaths
# 0     2021/1/1         4991           23
# %%
#D_frame

# %%
#D_frame.dtypes

# %%
active_columns=D_frame[["dates","active_cases"]]
active_df=active_columns.copy()

# %%
death_columns=D_frame[["dates","daily deaths"]]
death_df=death_columns.copy()

# %%
active_df.columns=['ds','y']
#active_df.dtypes

# %%
death_df.columns=['ds','y']

# %%
active_df['ds']=pd.to_datetime(active_df['ds'],format='%Y/%m/%d')

# %%
death_df['ds']=pd.to_datetime(death_df['ds'],format='%Y/%m/%d')

# %%
#active_df

# %%
ml=Prophet(interval_width=0.95,yearly_seasonality=True,weekly_seasonality=True)
model=ml.fit(active_df)
# Out:
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
future=ml.make_future_dataframe(periods=30,freq='D')
forecast=ml.predict(future)

# %%
forecast.tail(30)[['ds','yhat']] # yhat shows the 30 DAYS ACTIVE CASE FORECAST
# Out:
#             ds          yhat
# 282 2021-10-10   5798.755599
# 283 2021-10-11    -58.168033
# 284 2021-10-12   2661.234186
# 285 2021-10-13   1311.574987
# 286 2021-10-14  -2132.622900
# 287 2021-10-15  -5920.639780
# 288 2021-10-16  -9536.260433
# 289 2021-10-17 -14545.516807
# 290 2021-10-18 -22473.960077
# 291 2021-10-19 -21727.332455
# 292 2021-10-20 -24902.021795
# 293 2021-10-21 -29974.436489
# 294 2021-10-22 -35145.770729
# 295 2021-10-23 -39853.774635
# 296 2021-10-24 -45621.558265
# 297 2021-10-25 -53935.893505
# 298 2021-10-26 -53168.860176
# 299 2021-10-27 -55889.196175
# 300 2021-10-28 -60052.467208
# 301 2021-10-29 -63846.506102
# 302 2021-10-30 -66703.718477
# 303 2021-10-31 -70150.268898
# 304 2021-11-01 -75684.599782
# 305 2021-11-02 -71699.121257
# 306 2021-11-03 -70791.427373
# 307 2021-11-04 -70954.153760
# 308 2021-11-05 -70419.930246
# 309 2021-11-06 -68673.032667
# 310 2021-11-07 -67297.759319
# 311 2021-11-08 -67855.999215

# %%
ml.plot(forecast)

# %%
from fbprophet.diagnostics import cross_validation
data_val=cross_validation(ml,initial='223 days',period='1 days',horizon='1 days')
# Out:
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Making 58 forecasts with cutoffs between 2021-08-12 00:00:00 and 2021-10-08 00:00:00

# %%
from fbprophet.diagnostics import performance_metrics
data_metric=performance_metrics(df)
data_metric.head()
# Out:
#   horizon           mse        rmse          mae      mape     mdape  coverage
# 0  1 days  2.509671e+07  5009.66158  4027.482363  0.228169  0.173212  0.526316

# %%
df=data_val.drop(0,axis=0)

# %%
df
# Out:
#            ds          yhat    yhat_lower    yhat_upper      y     cutoff
# 1  2021-08-14  18649.113392  15231.423034  21945.710160  19451 2021-08-13
# 2  2021-08-15  17001.047407  13647.590065  20416.464843  18582 2021-08-14
# 3  2021-08-16  12924.608658   9655.356723  16342.223018  12294 2021-08-15
# 4  2021-08-17  16764.403963  13528.696970  20189.242807  21613 2021-08-16
# 5  2021-08-18  19622.814828  16235.832559  22751.028181  21427 2021-08-17
# 6  2021-08-19  20455.082129  16930.537628  23651.467096  21116 2021-08-18
# 7  2021-08-20  20593.137425  17170.971064  23985.236575  20224 2021-08-19
# 48 2021-09-30  16287.835269  12096.397511  20712.365228  15914 2021-09-29
# 49 2021-10-01  16161.546466  12077.334307  20353.864889  13834 2021-09-30
# 50 2021-10-02  15954.692332  11733.358625  20533.558933  13217 2021-10-01
# 51 2021-10-03  14455.881654  10017.908410  18673.758807  12297 2021-10-02
# 52 2021-10-04  10439.435986   6159.500027  14880.926411   8850 2021-10-03
# 53 2021-10-05  15301.351768  10886.686606  19889.035937   9735 2021-10-04
# 54 2021-10-06  14780.101268  10389.496611  19320.144455  12616 2021-10-05
# 55 2021-10-07   7778.533357   4070.185683  11959.966044  12288 2021-10-06
# 56 2021-10-08   7579.494462   3279.265194  11855.775480  10944 2021-10-07
# 57 2021-10-09  10216.070937   6059.345948  14603.763025   9470 2021-10-08

# %%
dat_val

# %%
from sklearn.metrics import mean_squared_error as mse
from math import sqrt
rmse=sqrt(mse(y1_test,predictions))

# %%
from fbprophet.plot import plot_cross_validation_metric
fig=plot_cross_validation_metric(data_val,metric='rmse')

# %%
#death_df

# %%
dl=Prophet(interval_width=0.95,yearly_seasonality=True)
model0=dl.fit(death_df)
# Out:
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
future2=dl.make_future_dataframe(periods=30,freq='D')
forecast2=dl.predict(future2)

# %%
forecast2.tail(30)[['ds','yhat']] # yhat shows the 30 DAYS DEATH FORECAST
# Out:
#             ds        yhat
# 282 2021-10-10  109.960536
# 283 2021-10-11  115.547026
# 284 2021-10-12  132.076053
# 285 2021-10-13  136.772841
# 286 2021-10-14  133.988952
# 287 2021-10-15  131.813337
# 288 2021-10-16  132.028280
# 289 2021-10-17  121.702974
# 290 2021-10-18  127.736849
# 291 2021-10-19  144.387519
# 292 2021-10-20  148.876720
# 293 2021-10-21  145.561188
# 294 2021-10-22  142.543620
# 295 2021-10-23  141.628306
# 296 2021-10-24  129.914162
# 297 2021-10-25  134.337307
# 298 2021-10-26  149.198060
# 299 2021-10-27  151.765769
# 300 2021-10-28  146.448438
# 301 2021-10-29  141.402337
# 302 2021-10-30  138.486214
# 303 2021-10-31  124.852884
# 304 2021-11-01  127.490375
# 305 2021-11-02  140.747534
# 306 2021-11-03  141.937578
# 307 2021-11-04  135.506539
# 308 2021-11-05  129.641870
# 309 2021-11-06  126.225828
# 310 2021-11-07  112.426442
# 311 2021-11-08  115.238258

# %%
dl.plot(forecast2)

# %%
from fbprophet.diagnostics import cross_validation
df_cv2=cross_validation(dl,initial='213 days',period='1 days',horizon='30 days')
df_cv2.head()
# Out:
# WARNING:fbprophet:Seasonality has period of 365.25 days which is larger than initial window. Consider increasing initial.
# INFO:fbprophet:Making 39 forecasts with cutoffs between 2021-08-02 00:00:00 and 2021-09-09 00:00:00
#           ds        yhat  yhat_lower  yhat_upper    y     cutoff
# 0 2021-08-03  108.244287   77.475753  139.533530  148 2021-08-02
# 1 2021-08-04  108.978118   77.146835  138.772043  108 2021-08-02
# 2 2021-08-05  103.472757   75.108415  135.086498  117 2021-08-02
# 3 2021-08-06  101.778367   69.721873  131.814011  187 2021-08-02
# 4 2021-08-07   99.234985   68.786554  130.423052  139 2021-08-02

# %%
from fbprophet.plot import plot_cross_validation_metric
fig=plot_cross_validation_metric(df_cv2,metric='rmse')
